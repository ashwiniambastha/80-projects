# %%
# !pip install -U langchain_xai
# !pip install langchain_community
# !pip install pypdf
# !pip install langchain_core
# !pip install -U sentence_transformers

# %%
import os

XAI_API_KEY = "xai-Epmc2UdYFNIvrMe2MeRqQxM653f6NCg9JGKedMqPoUbSekaDZawpIBWjKl8BrTO8UUMuC10qNKj04aV2"
os.environ["XAI_API_KEY"] = XAI_API_KEY

# %%
from langchain_xai import ChatXAI

chat = ChatXAI(
    model = "grok-4",
    api_key = XAI_API_KEY
)

#result = chat.invoke("who is roger federer, answer in 2 lines")

# %%
#print(result.content)
# Out:
# Roger Federer is a retired Swiss professional tennis player widely regarded as one of the greatest in history, known for his elegant style and sportsmanship.
# He won 20 Grand Slam singles titles, held the world No. 1 ranking for a record 310 weeks, and inspired millions with his career spanning over two decades.

# %% [markdown]
# ## PDF Based RAG Chatbot

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("/content/Satyajit Pattnaik - Lead AI Data Consultant.pdf")
documents = loader.load()

context = "\n\n".join(doc.page_content for doc in documents)

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(
    input_variables=["context", "question"],
    template="""
    You are an advanced resume evaluation assistant. Analyze the provided resume in the context document and
    score it out of 100 based on the following criteria: clarity, relevance, format, comprehensiveness, and keywords.

    Your response should be structured as follows:

    1. **Score**: Provide the score out of 100.
    2. **Strengths**: List at least three strengths found in the resume.
    3. **Weaknesses**: List at least three weaknesses or areas for improvement in the resume.
    4. **Skills Mentioned**: Identify and list the skills that are explicitly mentioned in the resume.
    5. **Recommended Skills**: Suggest additional skills that could enhance the resume's effectiveness.
    6. **Next Career Path**: Suggest what should be the next career paths for this candidate.

    Please ensure your analysis is clear and concise, providing actionable insights for improvement.
    """
)

# %%
# Prepare the question
question = "Please evaluate this resume."

# Format the prompt
formatted_prompt = prompt.format(context=context, question=question)

# Invoke the ChatXAI model
#response = chat.invoke(formatted_prompt)

# Output the response
#print(response)

# %%
for m in chat.stream(formatted_prompt):
  print(m.content, end="", flush = True)
# Out:
# 1. **Score**: 75/100
#    (Breakdown: Clarity - 18/20; Relevance - 16/20; Format - 15/20; Comprehensiveness - 13/20; Keywords - 13/20. The resume is solid in basics but lacks depth and optimization for modern job searches.)
#
# 2. **Strengths**:
#    - Clear and concise language that makes the resume easy to read and understand.
#    - Relevant experience directly tied to the field (e.g., software development roles), showing progression.
#    - Well-formatted sections with consistent bullet points and headings, improving scannability.
#
# 3. **Weaknesses**:
#    - Lacks quantifiable achievements (e.g., "developed apps" could be improved to "developed apps that increased user engagement by 30%") to demonstrate impact.
#    - Not comprehensive in education or certifications; additional details like GPA, relevant coursework, or online courses would add value.
# ...
